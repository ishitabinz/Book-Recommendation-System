# %%
# Importing libraries
import pandas as pd

def RecMenu():
    print("For book recommendation/rating - enter 1 and author review - enter 2")
    choice = input("recommendation/rating - enter 1 and author review - enter 2")
    if choice == "1":
        print(recommendation())
    elif choice == "2":
        print(authorSearch())
    else:
        print("Wrong Option! Please Retry")
        #RecMenu()

RecMenu()

def recommendation():
    
    # Read csv file into a pandas dataframe
    df = pd.read_csv("books.csv")
    df = df[df.language_code =='eng']
    df['Title'] = df['title'].str.split('(').str[0]
    print("Enter rating w/wo <rating> or random for book suggestion")
    search= input("enter to search: rating <lower limit> <upper limit> | random ")
    if search.lower()=="random":
        df_new= df.sample(replace=True)[['Title', 'authors',"rating"]]
        print("Title: ", df_new[['Title']].to_string(index=False, header=False))
        print("Author: ", df_new[['authors']].to_string(index=False, header=False))
        print("Rating: ", df_new[['rating']].to_string(index=False, header=False))
        return "Enjoy!"
    elif "rating" in search.lower():
            search=search.split()
            if len(search) == 1:            # if no range is entered
                l_rate = 0 ; u_rate = 5     # then default range is 0 to 5
            elif len(search) ==2:           # if only lower range is specified
                u_rate = 5                  # then default upper range to 5
            else:                           # if both ranges are present
                l_rate=float(search[1])
                u_rate=float(search[2])
            df_rate1 = df[df['rating'].astype(float) <= u_rate ]             # Filtering <= upper limit
            df_rate = df_rate1[df_rate1['rating'].astype(float) >= l_rate ]  # Filtering >= lower limit
            #
            df_new= df_rate.sample(replace=True)[['Title', 'authors',"rating"]]
            print("Title: ", df_new[['Title']].to_string(index=False, header=False))
            print("Author: ", df_new[['authors']].to_string(index=False, header=False))
            print("Rating: ", df_new[['rating']].to_string(index=False, header=False))
            return "Enjoy!"
#print(recommendation())


def authorSearch():
    
    # Read csv file into a pandas dataframe
    df = pd.read_csv("books.csv")
    df = df[df.language_code =='eng']
    df['Title'] = df['title'].str.split('(').str[0]
    print("Enter name of Author to display ")
    search= input("enter to search: author name <full name> ")
    #print("Author: ", search )
    df_author = df[df['authors'] == search ]
    if len(df_author) == 0:
        print("No book found for author named:", search)
    else:
        print("Total books by this author are ", len(df_author))
        sum = 0
        #print(df_author.iat([0],[0]))

        
        for item in df_author["rating"]:
            sum = sum + float(item)
        print("Average Rating: ", sum/len(df_author))
        
        #print(df_author.columns)
        nTitle = []
        nRating = [] 
        for val_ in ["title","rating"]:
            for item_ in df_author[val_]:
                if val_ == "title":
                    nTitle.append(item_)
                elif val_ =="rating":
                    nRating.append(item_)
        for num_ in range(1,len(nTitle)):
            print("Title: ",nTitle[num_],"\n    Rating: ",nRating[num_])
        

        #print("Title: ", df_new[['Title']].to_string(index=False, header=False))
        #print("Author: ", df_new[['authors']].to_string(index=False, header=False))
        #print("Rating: ", df_new[['rating']].to_string(index=False, header=False))
        """if search == df[['authors'].to_string(index=False, header=False)]:
        df_new= df.sample(replace=True)[['Title', 'authors',"rating"]]
        print("Title: ", df_new[['Title']].to_string(index=False, header=False))
        #print("Author: ", df_new[['authors']].to_string(index=False, header=False))
        print("Rating: ", df_new[['rating']].to_string(index=False, header=False))
        return "Enjoy!"
    else:                                                                            # if both ranges are present
                print("No books to show, sorry:(")
    """         
    return "Enjoy!"
#print(authorSearch())
# Out:
# For book recommendation/rating - enter 1 and author review - enter 2
# Enter name of Author to display
# Total books by this author are  20
# Average Rating:  3.934
# Title:  Bill Bryson's African Diary
#     Rating:  3.44
# Title:  Bryson's Dictionary of Troublesome Words: A Writer's Guide to Getting It Right
#     Rating:  3.87
# Title:  In a Sunburned Country
#     Rating:  4.07
# Title:  I'm a Stranger Here Myself: Notes on Returning to America After Twenty Years Away
#     Rating:  3.9
# Title:  The Lost Continent: Travels in Small Town America
#     Rating:  3.83
# Title:  Neither Here nor There: Travels in Europe
#     Rating:  3.86
# Title:  Notes from a Small Island
#     Rating:  3.91
# Title:  The Mother Tongue: English and How It Got That Way
#     Rating:  3.93
# Title:  A Short History of Nearly Everything
#     Rating:  4.21
# Title:  A Short History of Nearly Everything (Illustrated Edition)
#     Rating:  4.21
# Title:  A Walk in the Woods: Rediscovering America on the Appalachian Trail
#     Rating:  4.06
# Title:  A Walk in the Woods: Rediscovering America on the Appalachian Trail
#     Rating:  4.06
# Title:  The Lost Continent:  Travels in Small-town America
#     Rating:  3.83
# Title:  Made in America: An Informal History of the English Language in the United States
#     Rating:  3.91
# Title:  Bill Bryson's African Diary
#     Rating:  3.44
# Title:  Down Under
#     Rating:  4.07
# Title:  A Walk in the Woods: Rediscovering America on the Appalachian Trail
#     Rating:  4.06
# Title:  Bill Bryson: The Complete Notes
#     Rating:  4.09
# Title:  Journeys in English
#     Rating:  3.72
# Enjoy!
